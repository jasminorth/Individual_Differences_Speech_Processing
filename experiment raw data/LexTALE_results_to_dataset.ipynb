# %% [markdown]
# # LexTALE Results
#
# As part of our questionaire, we collected LexTALE results for all participants. We now parse them into a separate dataframe.
#
# > Code by: \
# *Jasmin Orth, LMU Munich*

# %% [markdown]
# ## Preparation

# %% [markdown]
# ### Imports

# %%
import pandas as pd

# %% [markdown]
# ### Load Dataset
# We read the dataset created by the questionaire.
# > If you run this, make sure its in the same folder as this code notebook.

# %%
lextale_df = pd.read_excel("data_valence_l1_english_2026.xlsx")

# %%
# run to see our dataset
print(f" Dataset: \n {lextale_df[:3]} \n")

# %% [markdown]
# ### Parse VP Codes and LexTALE results into new dataset

# %%
columns_to_extract = ["P101_01", "P105_01"]
new_df = lextale_df[columns_to_extract]

# Save the new data to a new Excel file (without modifying the original)
new_df.to_excel("LexTALE.xlsx", index=False)

print(f"New Excel file has been created: LexTALE.xlsx")
# Out:
# New Excel file has been created: LexTALE.xlsx
